# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
input_shape = (224,224,3)
image_size = (224, 224)
batch_size = 16

train_ds = keras.preprocessing.image_dataset_from_directory(
    directory = "D:/Projects/FINAL_Pruned_Dataset/FINAL_Pruned_Dataset/train/",
    validation_split=0.2,
    subset="training",
    seed=9,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = keras.preprocessing.image_dataset_from_directory(
    directory = "D:/Projects/FINAL_Pruned_Dataset/FINAL_Pruned_Dataset/train/",
    validation_split=0.2,
    subset="validation",
    seed=9,
    image_size=image_size,
    batch_size=batch_size,
)

test_ds = keras.preprocessing.image_dataset_from_directory(
    directory = "D:/Projects/FINAL_Pruned_Dataset/FINAL_Pruned_Dataset/test/",
    seed=24,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 8000 files belonging to 2 classes.
# Using 6400 files for training.
# Found 8000 files belonging to 2 classes.
# Using 1600 files for validation.
# Found 1174 files belonging to 2 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(0.1),
        #layers.experimental.preprocessing.RandomZoom(
           # height_factor = (0.2, 0.3),
           # width_factor=None,
           ## fill_mode='reflect', 
            #interpolation='bilinear'
           # )
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
inputs = keras.Input(shape=input_shape)
x = data_augmentation(inputs)
x = layers.experimental.preprocessing.Rescaling(1./255)(x)
#...  # Rest of the model

def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    x = layers.experimental.preprocessing.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(512, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv2D(128, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.AveragePooling2D(pool_size=(2, 2))(x)
    
    x = layers.Conv2D(128, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.AveragePooling2D(pool_size=(2, 2))(x)

    x = layers.Conv2D(128, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.AveragePooling2D(pool_size=(2, 2))(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.AveragePooling2D(pool_size=(2, 2))(x)


    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=2)
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, CSVLogger,ModelCheckpoint

# %%
filepath="D:/Updated-weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5" 

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=False
)

metrics = [
    keras.metrics.TruePositives(name = 'tp'),
    keras.metrics.FalsePositives(name = 'fp'),
    keras.metrics.TrueNegatives(name = 'tn'),
    keras.metrics.FalseNegatives(name = 'fn'),
    keras.metrics.BinaryAccuracy(name = 'accuracy'),
    keras.metrics.Precision(name = 'precision'),
    keras.metrics.Recall(name = 'recall'),
    keras.metrics.AUC(name = 'auc')
]
#checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

log_csv = tf.keras.callbacks.CSVLogger('D:/my_logs.csv', separator=',', append=False)

earlystop = tf.keras.callbacks.EarlyStopping(patience=10)

learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=5, 
                                            verbose=1, 
                                            factor=0.001,
                                            mode = 'auto',
                                            min_lr=0.00001)

# %%
print(model.summary())
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 224, 224, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 224, 224, 3)  0           sequential[1][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 512 14336       rescaling_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 512 2048        conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 512 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 112, 128 589952      activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 112, 112, 128 512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 56, 56, 128)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 128)  147584      average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 28, 28, 128)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 128)  147584      average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 14, 14, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 64)   73792       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 14, 14, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 7, 7, 64)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 7, 7, 64)     0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 7, 7, 128)    8896        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 7, 7, 128)    512         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, 7, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 7, 7, 128)    17664       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 7, 7, 128)    512         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 4, 4, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 4, 4, 128)    8320        average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 4, 4, 128)    0           max_pooling2d[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 4, 128)    0           add[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 4, 4, 256)    34176       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 256)    1024        separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, 4, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 4, 4, 256)    68096       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 256)    1024        separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 2, 2, 256)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 2, 2, 256)    33024       add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 2, 2, 256)    0           max_pooling2d_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2, 2, 256)    0           add_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 2, 2, 512)    133888      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 2, 2, 512)    2048        separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 2, 2, 512)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 2, 2, 512)    267264      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 2, 2, 512)    2048        separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 1, 1, 512)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 1, 512)    131584      add_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1, 1, 512)    0           max_pooling2d_2[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 1, 1, 1024)   529920      add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 1, 1, 1024)   4096        separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1, 1, 1024)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1024)         0           activation_11[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            1025        dropout[0][0]
# ==================================================================================================
# Total params: 2,222,209
# Trainable params: 2,214,657
# Non-trainable params: 7,552
# __________________________________________________________________________________________________
# None

# %%
epochs = 100

callbacks = [checkpoint,  log_csv, earlystop, learning_rate_reduction]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics= metrics,
)

history = model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds
                     
)
# Out:
# Epoch 1/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6857 - tp: 1940.0000 - fp: 1032.0000 - tn: 2166.0000 - fn: 1262.0000 - accuracy: 0.6416 - precision: 0.6528 - recall: 0.6059 - auc: 0.6942
# Epoch 00001: val_loss improved from inf to 3.43255, saving model to D:/Updated-weights-improvement-01-0.50.hdf5
# 400/400 [==============================] - 224s 559ms/step - loss: 0.6857 - tp: 1940.0000 - fp: 1032.0000 - tn: 2166.0000 - fn: 1262.0000 - accuracy: 0.6416 - precision: 0.6528 - recall: 0.6059 - auc: 0.6942 - val_loss: 3.4326 - val_tp: 798.0000 - val_fp: 802.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4988 - val_precision: 0.4988 - val_recall: 1.0000 - val_auc: 0.4917
# Epoch 2/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6067 - tp: 2196.0000 - fp: 956.0000 - tn: 2242.0000 - fn: 1006.0000 - accuracy: 0.6934 - precision: 0.6967 - recall: 0.6858 - auc: 0.7547
# Epoch 00002: val_loss improved from 3.43255 to 1.22253, saving model to D:/Updated-weights-improvement-02-0.55.hdf5
# 400/400 [==============================] - 202s 506ms/step - loss: 0.6067 - tp: 2196.0000 - fp: 956.0000 - tn: 2242.0000 - fn: 1006.0000 - accuracy: 0.6934 - precision: 0.6967 - recall: 0.6858 - auc: 0.7547 - val_loss: 1.2225 - val_tp: 93.0000 - val_fp: 9.0000 - val_tn: 793.0000 - val_fn: 705.0000 - val_accuracy: 0.5537 - val_precision: 0.9118 - val_recall: 0.1165 - val_auc: 0.6879
# Epoch 3/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5782 - tp: 2249.0000 - fp: 809.0000 - tn: 2389.0000 - fn: 953.0000 - accuracy: 0.7247 - precision: 0.7354 - recall: 0.7024 - auc: 0.7855
# Epoch 00003: val_loss improved from 1.22253 to 0.63743, saving model to D:/Updated-weights-improvement-03-0.68.hdf5
# 400/400 [==============================] - 201s 503ms/step - loss: 0.5782 - tp: 2249.0000 - fp: 809.0000 - tn: 2389.0000 - fn: 953.0000 - accuracy: 0.7247 - precision: 0.7354 - recall: 0.7024 - auc: 0.7855 - val_loss: 0.6374 - val_tp: 390.0000 - val_fp: 110.0000 - val_tn: 692.0000 - val_fn: 408.0000 - val_accuracy: 0.6762 - val_precision: 0.7800 - val_recall: 0.4887 - val_auc: 0.7394
# Epoch 4/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5735 - tp: 2237.0000 - fp: 790.0000 - tn: 2408.0000 - fn: 965.0000 - accuracy: 0.7258 - precision: 0.7390 - recall: 0.6986 - auc: 0.7829
# Epoch 00004: val_loss did not improve from 0.63743
# 400/400 [==============================] - 201s 502ms/step - loss: 0.5735 - tp: 2237.0000 - fp: 790.0000 - tn: 2408.0000 - fn: 965.0000 - accuracy: 0.7258 - precision: 0.7390 - recall: 0.6986 - auc: 0.7829 - val_loss: 1.3007 - val_tp: 776.0000 - val_fp: 754.0000 - val_tn: 48.0000 - val_fn: 22.0000 - val_accuracy: 0.5150 - val_precision: 0.5072 - val_recall: 0.9724 - val_auc: 0.7437
# Epoch 5/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5503 - tp: 2227.0000 - fp: 725.0000 - tn: 2473.0000 - fn: 975.0000 - accuracy: 0.7344 - precision: 0.7544 - recall: 0.6955 - auc: 0.8016
# Epoch 00005: val_loss did not improve from 0.63743
# 400/400 [==============================] - 201s 503ms/step - loss: 0.5503 - tp: 2227.0000 - fp: 725.0000 - tn: 2473.0000 - fn: 975.0000 - accuracy: 0.7344 - precision: 0.7544 - recall: 0.6955 - auc: 0.8016 - val_loss: 0.7209 - val_tp: 238.0000 - val_fp: 50.0000 - val_tn: 752.0000 - val_fn: 560.0000 - val_accuracy: 0.6187 - val_precision: 0.8264 - val_recall: 0.2982 - val_auc: 0.7060
# Epoch 6/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5547 - tp: 2290.0000 - fp: 762.0000 - tn: 2436.0000 - fn: 912.0000 - accuracy: 0.7384 - precision: 0.7503 - recall: 0.7152 - auc: 0.8012
# Epoch 00006: val_loss did not improve from 0.63743
# 400/400 [==============================] - 200s 501ms/step - loss: 0.5547 - tp: 2290.0000 - fp: 762.0000 - tn: 2436.0000 - fn: 912.0000 - accuracy: 0.7384 - precision: 0.7503 - recall: 0.7152 - auc: 0.8012 - val_loss: 4.0286 - val_tp: 796.0000 - val_fp: 801.0000 - val_tn: 1.0000 - val_fn: 2.0000 - val_accuracy: 0.4981 - val_precision: 0.4984 - val_recall: 0.9975 - val_auc: 0.5089
# Epoch 7/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5432 - tp: 2238.0000 - fp: 685.0000 - tn: 2513.0000 - fn: 964.0000 - accuracy: 0.7423 - precision: 0.7657 - recall: 0.6989 - auc: 0.8074
# Epoch 00007: val_loss did not improve from 0.63743
# 400/400 [==============================] - 201s 501ms/step - loss: 0.5432 - tp: 2238.0000 - fp: 685.0000 - tn: 2513.0000 - fn: 964.0000 - accuracy: 0.7423 - precision: 0.7657 - recall: 0.6989 - auc: 0.8074 - val_loss: 0.7586 - val_tp: 120.0000 - val_fp: 19.0000 - val_tn: 783.0000 - val_fn: 678.0000 - val_accuracy: 0.5644 - val_precision: 0.8633 - val_recall: 0.1504 - val_auc: 0.7187
# Epoch 8/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5298 - tp: 2310.0000 - fp: 717.0000 - tn: 2481.0000 - fn: 892.0000 - accuracy: 0.7486 - precision: 0.7631 - recall: 0.7214 - auc: 0.8193
# Epoch 00008: val_loss did not improve from 0.63743
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1e-05.
# 400/400 [==============================] - 201s 501ms/step - loss: 0.5298 - tp: 2310.0000 - fp: 717.0000 - tn: 2481.0000 - fn: 892.0000 - accuracy: 0.7486 - precision: 0.7631 - recall: 0.7214 - auc: 0.8193 - val_loss: 1.2388 - val_tp: 43.0000 - val_fp: 5.0000 - val_tn: 797.0000 - val_fn: 755.0000 - val_accuracy: 0.5250 - val_precision: 0.8958 - val_recall: 0.0539 - val_auc: 0.6578
# Epoch 9/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5018 - tp: 2510.0000 - fp: 821.0000 - tn: 2377.0000 - fn: 692.0000 - accuracy: 0.7636 - precision: 0.7535 - recall: 0.7839 - auc: 0.8370
# Epoch 00009: val_loss improved from 0.63743 to 0.50564, saving model to D:/Updated-weights-improvement-09-0.75.hdf5
# 400/400 [==============================] - 201s 503ms/step - loss: 0.5018 - tp: 2510.0000 - fp: 821.0000 - tn: 2377.0000 - fn: 692.0000 - accuracy: 0.7636 - precision: 0.7535 - recall: 0.7839 - auc: 0.8370 - val_loss: 0.5056 - val_tp: 526.0000 - val_fp: 126.0000 - val_tn: 676.0000 - val_fn: 272.0000 - val_accuracy: 0.7513 - val_precision: 0.8067 - val_recall: 0.6591 - val_auc: 0.8406
# Epoch 10/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4953 - tp: 2490.0000 - fp: 784.0000 - tn: 2414.0000 - fn: 712.0000 - accuracy: 0.7663 - precision: 0.7605 - recall: 0.7776 - auc: 0.8411
# Epoch 00010: val_loss improved from 0.50564 to 0.49900, saving model to D:/Updated-weights-improvement-10-0.76.hdf5
# 400/400 [==============================] - 203s 507ms/step - loss: 0.4953 - tp: 2490.0000 - fp: 784.0000 - tn: 2414.0000 - fn: 712.0000 - accuracy: 0.7663 - precision: 0.7605 - recall: 0.7776 - auc: 0.8411 - val_loss: 0.4990 - val_tp: 532.0000 - val_fp: 122.0000 - val_tn: 680.0000 - val_fn: 266.0000 - val_accuracy: 0.7575 - val_precision: 0.8135 - val_recall: 0.6667 - val_auc: 0.8426
# Epoch 11/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4833 - tp: 2506.0000 - fp: 763.0000 - tn: 2435.0000 - fn: 696.0000 - accuracy: 0.7720 - precision: 0.7666 - recall: 0.7826 - auc: 0.8483
# Epoch 00011: val_loss did not improve from 0.49900
# 400/400 [==============================] - 206s 514ms/step - loss: 0.4833 - tp: 2506.0000 - fp: 763.0000 - tn: 2435.0000 - fn: 696.0000 - accuracy: 0.7720 - precision: 0.7666 - recall: 0.7826 - auc: 0.8483 - val_loss: 0.5097 - val_tp: 506.0000 - val_fp: 103.0000 - val_tn: 699.0000 - val_fn: 292.0000 - val_accuracy: 0.7531 - val_precision: 0.8309 - val_recall: 0.6341 - val_auc: 0.8426
# Epoch 12/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4852 - tp: 2499.0000 - fp: 725.0000 - tn: 2473.0000 - fn: 703.0000 - accuracy: 0.7769 - precision: 0.7751 - recall: 0.7804 - auc: 0.8477
# Epoch 00012: val_loss did not improve from 0.49900
# 400/400 [==============================] - 204s 510ms/step - loss: 0.4852 - tp: 2499.0000 - fp: 725.0000 - tn: 2473.0000 - fn: 703.0000 - accuracy: 0.7769 - precision: 0.7751 - recall: 0.7804 - auc: 0.8477 - val_loss: 0.5259 - val_tp: 476.0000 - val_fp: 86.0000 - val_tn: 716.0000 - val_fn: 322.0000 - val_accuracy: 0.7450 - val_precision: 0.8470 - val_recall: 0.5965 - val_auc: 0.8404
# Epoch 13/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4911 - tp: 2473.0000 - fp: 729.0000 - tn: 2469.0000 - fn: 729.0000 - accuracy: 0.7722 - precision: 0.7723 - recall: 0.7723 - auc: 0.8439
# Epoch 00013: val_loss did not improve from 0.49900
# 400/400 [==============================] - 202s 505ms/step - loss: 0.4911 - tp: 2473.0000 - fp: 729.0000 - tn: 2469.0000 - fn: 729.0000 - accuracy: 0.7722 - precision: 0.7723 - recall: 0.7723 - auc: 0.8439 - val_loss: 0.5146 - val_tp: 489.0000 - val_fp: 89.0000 - val_tn: 713.0000 - val_fn: 309.0000 - val_accuracy: 0.7513 - val_precision: 0.8460 - val_recall: 0.6128 - val_auc: 0.8415
# Epoch 14/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4807 - tp: 2474.0000 - fp: 714.0000 - tn: 2484.0000 - fn: 728.0000 - accuracy: 0.7747 - precision: 0.7760 - recall: 0.7726 - auc: 0.8495
# Epoch 00014: val_loss did not improve from 0.49900
# 400/400 [==============================] - 204s 510ms/step - loss: 0.4807 - tp: 2474.0000 - fp: 714.0000 - tn: 2484.0000 - fn: 728.0000 - accuracy: 0.7747 - precision: 0.7760 - recall: 0.7726 - auc: 0.8495 - val_loss: 0.5188 - val_tp: 480.0000 - val_fp: 87.0000 - val_tn: 715.0000 - val_fn: 318.0000 - val_accuracy: 0.7469 - val_precision: 0.8466 - val_recall: 0.6015 - val_auc: 0.8435
# Epoch 15/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4823 - tp: 2463.0000 - fp: 704.0000 - tn: 2494.0000 - fn: 739.0000 - accuracy: 0.7745 - precision: 0.7777 - recall: 0.7692 - auc: 0.8497
# Epoch 00015: val_loss did not improve from 0.49900
# 400/400 [==============================] - 203s 509ms/step - loss: 0.4823 - tp: 2463.0000 - fp: 704.0000 - tn: 2494.0000 - fn: 739.0000 - accuracy: 0.7745 - precision: 0.7777 - recall: 0.7692 - auc: 0.8497 - val_loss: 0.5092 - val_tp: 506.0000 - val_fp: 102.0000 - val_tn: 700.0000 - val_fn: 292.0000 - val_accuracy: 0.7538 - val_precision: 0.8322 - val_recall: 0.6341 - val_auc: 0.8415
# Epoch 16/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4886 - tp: 2457.0000 - fp: 740.0000 - tn: 2458.0000 - fn: 745.0000 - accuracy: 0.7680 - precision: 0.7685 - recall: 0.7673 - auc: 0.8453
# Epoch 00016: val_loss did not improve from 0.49900
# 400/400 [==============================] - 204s 510ms/step - loss: 0.4886 - tp: 2457.0000 - fp: 740.0000 - tn: 2458.0000 - fn: 745.0000 - accuracy: 0.7680 - precision: 0.7685 - recall: 0.7673 - auc: 0.8453 - val_loss: 0.5106 - val_tp: 490.0000 - val_fp: 92.0000 - val_tn: 710.0000 - val_fn: 308.0000 - val_accuracy: 0.7500 - val_precision: 0.8419 - val_recall: 0.6140 - val_auc: 0.8457
# Epoch 17/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4803 - tp: 2483.0000 - fp: 705.0000 - tn: 2493.0000 - fn: 719.0000 - accuracy: 0.7775 - precision: 0.7789 - recall: 0.7755 - auc: 0.8518
# Epoch 00017: val_loss did not improve from 0.49900
# 400/400 [==============================] - 205s 513ms/step - loss: 0.4803 - tp: 2483.0000 - fp: 705.0000 - tn: 2493.0000 - fn: 719.0000 - accuracy: 0.7775 - precision: 0.7789 - recall: 0.7755 - auc: 0.8518 - val_loss: 0.5053 - val_tp: 502.0000 - val_fp: 94.0000 - val_tn: 708.0000 - val_fn: 296.0000 - val_accuracy: 0.7563 - val_precision: 0.8423 - val_recall: 0.6291 - val_auc: 0.8463
# Epoch 18/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4735 - tp: 2488.0000 - fp: 687.0000 - tn: 2511.0000 - fn: 714.0000 - accuracy: 0.7811 - precision: 0.7836 - recall: 0.7770 - auc: 0.8558
# Epoch 00018: val_loss did not improve from 0.49900
# 400/400 [==============================] - 205s 512ms/step - loss: 0.4735 - tp: 2488.0000 - fp: 687.0000 - tn: 2511.0000 - fn: 714.0000 - accuracy: 0.7811 - precision: 0.7836 - recall: 0.7770 - auc: 0.8558 - val_loss: 0.5142 - val_tp: 498.0000 - val_fp: 88.0000 - val_tn: 714.0000 - val_fn: 300.0000 - val_accuracy: 0.7575 - val_precision: 0.8498 - val_recall: 0.6241 - val_auc: 0.8438
# Epoch 19/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4772 - tp: 2481.0000 - fp: 697.0000 - tn: 2501.0000 - fn: 721.0000 - accuracy: 0.7784 - precision: 0.7807 - recall: 0.7748 - auc: 0.8541
# Epoch 00019: val_loss did not improve from 0.49900
# 400/400 [==============================] - 200s 499ms/step - loss: 0.4772 - tp: 2481.0000 - fp: 697.0000 - tn: 2501.0000 - fn: 721.0000 - accuracy: 0.7784 - precision: 0.7807 - recall: 0.7748 - auc: 0.8541 - val_loss: 0.5207 - val_tp: 481.0000 - val_fp: 81.0000 - val_tn: 721.0000 - val_fn: 317.0000 - val_accuracy: 0.7513 - val_precision: 0.8559 - val_recall: 0.6028 - val_auc: 0.8468
# Epoch 20/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4696 - tp: 2495.0000 - fp: 702.0000 - tn: 2496.0000 - fn: 707.0000 - accuracy: 0.7798 - precision: 0.7804 - recall: 0.7792 - auc: 0.8587
# Epoch 00020: val_loss did not improve from 0.49900
# 400/400 [==============================] - 200s 501ms/step - loss: 0.4696 - tp: 2495.0000 - fp: 702.0000 - tn: 2496.0000 - fn: 707.0000 - accuracy: 0.7798 - precision: 0.7804 - recall: 0.7792 - auc: 0.8587 - val_loss: 0.5171 - val_tp: 493.0000 - val_fp: 87.0000 - val_tn: 715.0000 - val_fn: 305.0000 - val_accuracy: 0.7550 - val_precision: 0.8500 - val_recall: 0.6178 - val_auc: 0.8467

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
result = model.evaluate(test_ds)
print(result)
# Out:
# 74/74 [==============================] - 27s 368ms/step - loss: 0.5725 - tp: 370.0000 - fp: 123.0000 - tn: 465.0000 - fn: 216.0000 - accuracy: 0.7112 - precision: 0.7505 - recall: 0.6314 - auc: 0.8000
# [0.572499692440033, 370.0, 123.0, 465.0, 216.0, 0.7112436294555664, 0.750507116317749, 0.6313993334770203, 0.8000336289405823]

# %%
import seaborn as sns
sns.heatmap(cnf_matrix, cmap='Blues', annot= True)
# Out:
# <AxesSubplot:>

# %%
model.save("D:/UpdatedLR100Epochs80train.h5")

# %%
from numpy import loadtxt
from keras.models import load_model
 

model = load_model('D:/Updated-weights-improvement-72-0.78.hdf5')
# summarize model.
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 224, 224, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 224, 224, 3)  0           sequential[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 512 14336       rescaling_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 512 2048        conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 512 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 112, 128 589952      activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 112, 112, 128 512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 56, 56, 128)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 128)  147584      average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 28, 28, 128)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 128)  147584      average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 14, 14, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 64)   73792       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 14, 14, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 7, 7, 64)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 7, 7, 64)     0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 7, 7, 128)    8896        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 7, 7, 128)    512         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, 7, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 7, 7, 128)    17664       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 7, 7, 128)    512         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 4, 4, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 4, 4, 128)    8320        average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 4, 4, 128)    0           max_pooling2d[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 4, 128)    0           add[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 4, 4, 256)    34176       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 256)    1024        separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, 4, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 4, 4, 256)    68096       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 256)    1024        separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 2, 2, 256)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 2, 2, 256)    33024       add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 2, 2, 256)    0           max_pooling2d_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2, 2, 256)    0           add_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 2, 2, 512)    133888      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 2, 2, 512)    2048        separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 2, 2, 512)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 2, 2, 512)    267264      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 2, 2, 512)    2048        separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 1, 1, 512)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 1, 512)    131584      add_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1, 1, 512)    0           max_pooling2d_2[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 1, 1, 1024)   529920      add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 1, 1, 1024)   4096        separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1, 1, 1024)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1024)         0           activation_11[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            1025        dropout[0][0]
# ==================================================================================================
# Total params: 2,222,209
# Trainable params: 2,214,657
# Non-trainable params: 7,552
# __________________________________________________________________________________________________

# %%
score = model.evaluate(test_ds, verbose=1)
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# 74/74 [==============================] - 10s 137ms/step - loss: 0.5383 - accuracy: 0.7411
# accuracy: 74.11%

# %%
result = model.evaluate(other_test)
print(result)
